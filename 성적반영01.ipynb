# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy  
import pandas as pd 
import os
import random

query_txt = input('    1.크롤링 할 영화의 제목을 입력하세요: ')
query_url = 'https://movie.naver.com'

cnt = int(input('    2.크롤링 할 리뷰건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)

f_dir = input("    3.파일을 저장할 폴더명만 쓰세요(예:c:\\temp\\):")
print("-" *80)
print("    요청하신 데이터를 수집 중이오니 잠시만 기다려 주세요~~~~")


now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'



s_time = time.time( )

path = "c:/Temp/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get(query_url)
time.sleep(1)


element = driver.find_element_by_id("ipt_tx_srch")
element.send_keys(query_txt)
driver.find_element_by_xpath("""//*[@id="jSearchArea"]/div/button""").click()
driver.find_element_by_xpath("""//*[@id="old_content"]/ul[2]/li/dl/dt/a""").click()
        

driver.find_element_by_link_text("평점").click()



driver.switch_to.frame('pointAfterListIframe')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')


result= soup.find('div', class_='score_total').find('strong','total').find_all('em')
result2 = result[0].get_text()

print("=" *80)
result3 = result2.replace(",","")
result4 = re.search("\d+",result3)
search_cnt = int(result4.group())

if cnt > search_cnt :
    cnt = search_cnt

print("전체 검색 결과 건수 :",search_cnt,"건")
print("실제 최종 출력 건수",cnt)

print("\n")
page_cnt = math.ceil(cnt / 10)
print("크롤링 할 총 페이지 번호: ",page_cnt)
print("=" *80)


score=[]
review=[]
writer=[]
date=[]
gogam2=[]
good=[]
bad=[]
data_list2=[]

count = 0         
click_count = 1   

while ( click_count <= page_cnt )  :
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            r_score_result = soup.find('div', class_='score_result').find('ul')
            slist = r_score_result.find_all('li')

            for li in slist:

                count += 1
                
                f = open(ff_name, 'a',encoding='UTF-8')
            
                print("\n")
                print("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count))
                r_score = li.find('div', class_='star_score').find('em').get_text()
                print("1.별점:","*"*int(r_score),": ", r_score)
                score.append(r_score)
                f.write("\n")
                f.write("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count) + "\n")
                f.write("1.별점:"+r_score + "\n")
            
                r_review = li.find('div', class_='score_reple').find('p').get_text()
                print("2.리뷰내용:",r_review)
                f.write("2.리뷰내용:" + r_review + "\n")
                review.append(r_review)
         
                data_list = li.find('div',class_='score_reple').find_all('em')
                r_writer = data_list[0].find('span').get_text()
                print("3.작성자:",r_writer)
                f.write("3.작성자:" + r_writer + "\n")
                writer.append(r_writer)
                
                r_date = data_list[1].text
                print('4.작성일자:',r_date)
                f.write("4.작성일자:" + r_date + "\n")
                date.append(r_date)
            
                gogam = li.find('div', class_='btn_area').find_all('strong')
                r_good = gogam[0].text
                print('5.공감:',r_good)
                f.write("5.공감:" + r_good + "\n")
                good.append(r_good)
                
                r_bad = gogam[1].text
                print('6.비공감:', r_bad)
                f.write("6.비공감:" + r_bad + "\n")
                bad.append(r_bad)
                print("\n")

                

                if count == cnt :
                    break
            
            time.sleep(random.randrange(1,2))  

            click_count += 1
            
            if click_count > page_cnt :
                break
            else :
                driver.find_element_by_link_text("%s" %click_count).click()

            time.sleep(random.randrange(1,2))  # 3-8 초 사이에 랜덤으로 시간 선택



naver_movie = pd.DataFrame()
naver_movie['별점(평점)']=score
naver_movie['작성자']=writer
naver_movie['작성일자']=date
naver_movie['공감횟수']=good
naver_movie['비공감횟수']=bad


naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)


naver_movie.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time


print("\n") 
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
#     1.크롤링 할 영화의 제목을 입력하세요: 미나리
#     2.크롤링 할 리뷰건수는 몇건입니까?: 15
#     3.파일을 저장할 폴더명만 쓰세요(예:c:\temp\):c:\sns_\
# --------------------------------------------------------------------------------
#     요청하신 데이터를 수집 중이오니 잠시만 기다려 주세요~~~~
# ================================================================================
# 전체 검색 결과 건수 : 5004 건
# 실제 최종 출력 건수 15
#
#
# 크롤링 할 총 페이지 번호:  2
# ================================================================================
#
#
# 총 15 건 중 1 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																기대보다는 스토리가 큰 감흥은 없습니다연기는 잔잔하게 볼 만 합니다
#
#
#
#
#
# 3.작성자: drjy****
# 4.작성일자: 2021.03.03 16:31
# 5.공감: 744
# 6.비공감: 229
#
#
#
#
# 총 15 건 중 2 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																약간 지루하고 결말이 아쉬워요.
#
#
#
#
#
# 3.작성자: 그자리(t3s2****)
# 4.작성일자: 2021.03.03 19:18
# 5.공감: 826
# 6.비공감: 333
#
#
#
#
# 총 15 건 중 3 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																울리지 않아서 더 좋았어요.
#
#
#
#
#
# 3.작성자: 납득이(csj7****)
# 4.작성일자: 2021.03.03 12:58
# 5.공감: 483
# 6.비공감: 72
#
#
#
#
# 총 15 건 중 4 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
# 																		메시지는 차치하고 감각적으로(시각, 청각) 황홀했다. 영화는 가능하고, 소설은 불가능한 것. 영화는 도달할 수 있고, 소설은 도달할 수 없는 것. 영화는 체험시킬 수 있고, 소설은 체험시킬 수 없는 것. 더 확장하면...
#
#
#
#
# 3.작성자: koreapridehyun(tv17****)
# 4.작성일자: 2021.03.03 12:20
# 5.공감: 852
# 6.비공감: 488
#
#
#
#
# 총 15 건 중 5 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
# 																		개봉일을 기다려, 모처럼 팔순의 친정어머니와 롯데 시네마에서 보았어요. 잔잔한 시냇물이 흐르는 계곡에 미나리 밭을 일구는 우리들의 어머니 또는 할머니의 강인한 생존력이란! 대지의 후손들이라면 누구나 배꼽 아래 단전으...
#
#
#
#
# 3.작성자: 색동보자기(ande****)
# 4.작성일자: 2021.03.03 20:59
# 5.공감: 446
# 6.비공감: 101
#
#
#
#
# 총 15 건 중 6 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																음악이 잔잔하고 데이빗 넘 귀엽습니다
#
#
#
#
#
# 3.작성자: HJMom(opti****)
# 4.작성일자: 2021.03.03 12:03
# 5.공감: 404
# 6.비공감: 64
#
#
#
#
# 총 15 건 중 7 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																잔잔한 영화생각보다 큰 감동은 아니었다.기대가 컸나?
#
#
#
#
#
# 3.작성자: 푸름이(min9****)
# 4.작성일자: 2021.03.03 16:27
# 5.공감: 407
# 6.비공감: 125
#
#
#
#
# 총 15 건 중 8 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																하....  이것이 제 심사평입니다. 이런 게 바로 영화 아니겠습니다. 오늘 하루 하.. 할듯..
#
#
#
#
#
# 3.작성자: 아르슬랭(gor3****)
# 4.작성일자: 2021.03.03 11:12
# 5.공감: 445
# 6.비공감: 211
#
#
#
#
# 총 15 건 중 9 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																보고나니 아름다기도 하고 먹먹하네요.
#
#
#
#
#
# 3.작성자: 문지영(clec****)
# 4.작성일자: 2021.03.03 13:32
# 5.공감: 279
# 6.비공감: 71
#
#
#
#
# 총 15 건 중 10 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																어려운 시대를 담담히 풀어나갔거 같습니다.
#
#
#
#
#
# 3.작성자: 박종현(hyh3****)
# 4.작성일자: 2021.03.03 11:51
# 5.공감: 245
# 6.비공감: 67
#
#
#
#
# 총 15 건 중 11 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																평양냉면 같은 영화. 막상 기대했다가 보면 이게뭐야? 할지도 모르지만 극장을 나선 뒤에도 잔잔하게 울림을 주는 영화
#
#
#
#
#
# 3.작성자: 김승연(at05****)
# 4.작성일자: 2021.03.05 10:06
# 5.공감: 138
# 6.비공감: 32
#
#
#
#
# 총 15 건 중 12 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
# 																		이 영화자체가 미나리같다. 그리고 이 영화에 나오는 인물들도 미나리같다. 특별하고 화려하진 않지만 강인하고  자꾸 머릿속에 이 가족의 현재와 미래가 궁금해지고 응원하게 된다.그들의 모습속에서 가장으로써의 모습, 어머...
#
#
#
#
# 3.작성자: TOTO(0071****)
# 4.작성일자: 2021.03.03 23:07
# 5.공감: 138
# 6.비공감: 32
#
#
#
#
# 총 15 건 중 13 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
# 스포일러가 포함된 감상평입니다. 감상평 보기
#
#
#
# 																		부모님의 높아지는 언성에 숨어서 마음 졸였던 아이, 축축한 이불에 몰래 흔적을 지웠던 아침, 그저 풀 위를 달리고 싶었던 순수했던 마음, 그리고 그 때는 보이지 않았던 아버지의 삶의 무게까지. 잔잔하지만 재치있고, ...
#
#
#
#
# 3.작성자: 디노(dino****)
# 4.작성일자: 2021.03.05 01:10
# 5.공감: 129
# 6.비공감: 24
#
#
#
#
# 총 15 건 중 14 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																롸...? 난 또 미나리 키워서 대박이라도 나는 줄...
#
#
#
#
#
# 3.작성자: RubyU(ruby****)
# 4.작성일자: 2021.03.07 20:22
# 5.공감: 160
# 6.비공감: 55
#
#
#
#
# 총 15 건 중 15 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																언론플레이에 당했다는느낌. 그냥 잔잔한 독립영화. 기대가 너무컷나? 스토리와 플롯이 엉성하다. 계속 뭔가 나오겠지 나오겠지 하다 끝남
#
#
#
#
#
# 3.작성자: penn(penn****)
# 4.작성일자: 2021.03.05 08:59
# 5.공감: 164
# 6.비공감: 59
#
#
#
#
# ================================================================================
# 1.요청된 총 15 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 15 건입니다
# 2.총 소요시간은 13.2 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\sns_\2021-06-13-16-42-16-미나리\2021-06-13-16-42-16-미나리.txt
# 4.파일 저장 완료: csv 파일명 : c:\sns_\2021-06-13-16-42-16-미나리\2021-06-13-16-42-16-미나리.csv
# 5.파일 저장 완료: xls 파일명 : c:\sns_\2021-06-13-16-42-16-미나리\2021-06-13-16-42-16-미나리.xls
# ================================================================================
